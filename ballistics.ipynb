# %% [markdown]
# # Ballistics and the Range Equation
# This is an investigation of the so-called *range equation*: $d=\frac {v^2} g\sin 2\theta$

# %%
from math import radians, sin, pi
from numpy import linspace
import matplotlib.pyplot as plt

# %%
def rangeformula(v, theta):
    """
    Inputs: 
    v - velocity in m/s
    theta - launch angle with respect to horizon in radians
    Returns: 
    Impact distance in m
    """
    return (v**2)*sin(2*(theta))/9.807

# %%
def degrangeformula(v, theta):
    """
    Inputs: 
    v - velocity in m/s
    theta - launch angle with respect to horizon in degrees
    Returns: 
    Impact distance in m
    """
    return (v**2)*sin(2*radians(theta))/9.807

# %%
angledegrees = linspace(0, 90, num=200)

# %%
rangefromdegrees=[]
for x in angledegrees:
    rangefromdegrees.append(degrangeformula(100, x))

# %%
angleradians = linspace(0, 1.57, num=200)

# %%
rangefromradians=[]
for x in angleradians:
    rangefromradians.append(rangeformula(100, x))

# %%
velocities=linspace(0,100)

# %%
rangefromvelocity=[]
for x in velocities:
    rangefromvelocity.append(rangeformula(x, 45))

# %%
plt.plot(angledegrees, rangefromdegrees)
plt.title('Range as a function of angle at 100 m/s')
plt.xlabel('Angle (degrees)')
plt.ylabel('Range (meters)')
plt.show()

# %%
rangeforangle100 = [degrangeformula(100, radians(angle)) for angle in angledegrees]
rangeforangle200 = [degrangeformula(200, radians(angle)) for angle in angledegrees]
plt.plot(angledegrees, rangeforangle100, label="100 m/s")
plt.legend()
plt.plot(angledegrees, rangeforangle200, label="200 m/s")
plt.legend()
plt.title('Range as a function of angle at various velocities')
plt.xlabel('Angle (degrees)')
plt.ylabel('Range (meters)')
plt.show()

# %%
plt.plot(angleradians, rangefromradians)
plt.title('Range as a function of angle at 100 m/s')
plt.xlabel('Angle (radians)')
plt.ylabel('Range (meters)')
plt.show()

# %%
plt.plot(velocities, rangefromvelocity)
plt.title('Range as a function of velocity at 45 degrees')
plt.xlabel('Velocity (meters/second)')
plt.ylabel('Range (meters)')
plt.show()

# %%
rangeforvelocity15 = [degrangeformula(velocity, 15) for velocity in velocities]
rangeforvelocity30 = [degrangeformula(velocity, 30) for velocity in velocities]
rangeforvelocity45 = [degrangeformula(velocity, 45) for velocity in velocities]
rangeforvelocity60 = [degrangeformula(velocity, 60) for velocity in velocities]
rangeforvelocity75 = [degrangeformula(velocity, 75) for velocity in velocities]
plt.plot(velocities, rangeforvelocity15, label="15 degrees")
plt.legend()
plt.plot(velocities, rangeforvelocity30, label="30 degrees")
plt.legend()
plt.plot(velocities, rangeforvelocity45, label="45 degrees")
plt.legend()
plt.plot(velocities, rangeforvelocity60, label="60 degrees")
plt.legend()
plt.plot(velocities, rangeforvelocity75, label="75 degrees")
plt.legend()
plt.title('Range as a function of velocity at various angles')
plt.xlabel('Velocity (meters/second)')
plt.ylabel('Range (meters)')
plt.show()

# %% [markdown]
# Some of the advantages of the Jupyter notebook include the visibility of all that goes into making the output, unlike in the spreadsheet. The data is less easily corruptible as compared with a spreadsheet.
# The disadvantages are that it requires more skill and knowledge to use than a spreadsheet.
